# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()
ts.plot()
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index,columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
plt.figure(); 
df.plot(); 
plt.legend(loc='best')

# %%
np.loadtxt('C:/KJ/Temp/DAT_ASCII_EURUSD_T_201505.csv',delimiter=',', dtype={'names': ('dt', 'start', 'end'),
...                      'formats': ('np.datetime64[ms]', 'f4', 'f4')})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-6852bc2281e5> in <module>()
#       1 np.loadtxt('C:/KJ/Temp/DAT_ASCII_EURUSD_T_201505.csv',delimiter=',', dtype={'names': ('dt', 'start', 'end'),
# ----> 2                      'formats': ('np.datetime64[ms]', 'f4', 'f4')})
#
# C:\KJ\Software\Anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     803     try:
#     804         # Make sure we're dealing with a proper dtype
# --> 805         dtype = np.dtype(dtype)
#     806         defconv = _getconv(dtype)
#     807
#
# TypeError: data type "np.datetime64[ms]" not understood

# %%
import dateutil.parser as parser

# %%
parser.parse('Jan 1')
# Out:
# datetime.datetime(2015, 1, 1, 0, 0)

# %%
parser.parse('20150501 000000587')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-3965feecf4e2> in <module>()
# ----> 1 parser.parse('20150501 000000587')
#
# C:\KJ\Software\Anaconda3\lib\site-packages\dateutil\parser.py in parse(timestr, parserinfo, **kwargs)
#     980         return parser(parserinfo).parse(timestr, **kwargs)
#     981     else:
# --> 982         return DEFAULTPARSER.parse(timestr, **kwargs)
#     983
#     984
#
# C:\KJ\Software\Anaconda3\lib\site-packages\dateutil\parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     388
#     389         if res is None:
# --> 390             raise ValueError("Unknown string format")
#     391
#     392         repl = {}
#
# ValueError: Unknown string format

# %%
parser.parse('20150531 235959953')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-ceec265db5be> in <module>()
# ----> 1 parser.parse('20150531 235959953')
#
# C:\KJ\Software\Anaconda3\lib\site-packages\dateutil\parser.py in parse(timestr, parserinfo, **kwargs)
#     980         return parser(parserinfo).parse(timestr, **kwargs)
#     981     else:
# --> 982         return DEFAULTPARSER.parse(timestr, **kwargs)
#     983
#     984
#
# C:\KJ\Software\Anaconda3\lib\site-packages\dateutil\parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     388
#     389         if res is None:
# --> 390             raise ValueError("Unknown string format")
#     391
#     392         repl = {}
#
# ValueError: Unknown string format

# %%
import io
d = io.StringIO("20150531 235855453,1.095000,1.095050,0\n20150531 235902953,1.095020,1.095060,0")
np.loadtxt(d, unpack=False, delimiter=',',dtype={'names': ('time', 'start', 'end','zero'),
                     'formats': ('S18', 'float', 'float','i4')})
# Out:
# array([(b'20150531 235855453', 1.095, 1.09505, 0),
#        (b'20150531 235902953', 1.09502, 1.09506, 0)],
#       dtype=[('time', 'S18'), ('start', '<f8'), ('end', '<f8'), ('zero', '<i4')])

# %%
np.loadtxt('C:/KJ/Temp/DAT_ASCII_EURUSD_T_201505.csv', unpack=False, delimiter=',',dtype={'names': ('time', 'start', 'end','zero'),
                     'formats': ('S18', 'float', 'float','i4')})
# Out:
# array([(b'20150501 000000587', 1.12083, 1.12087, 0),
#        (b'20150501 000005587', 1.12083, 1.12086, 0),
#        (b'20150501 000018087', 1.12081, 1.12086, 0), ...,
#        (b'20150531 235943703', 1.09499, 1.09504, 0),
#        (b'20150531 235951953', 1.09499, 1.09503, 0),
#        (b'20150531 235959953', 1.09499, 1.09504, 0)],
#       dtype=[('time', 'S18'), ('start', '<f8'), ('end', '<f8'), ('zero', '<i4')])

# %%
rows1500 = np.loadtxt('C:/KJ/Temp/DAT_ASCII_EURUSD_T_201505_1500Rows.csv', unpack=False, delimiter=',',dtype={'names': ('time', 'start', 'end','zero'),
                     'formats': ('S18', 'float', 'float','i4')})
df = pd.DataFrame(rows1500, )

# %%
df.plot()

# %%
rows1500
# Out:
# array([(b'20150501 000000587', 1.12083, 1.12087, 0),
#        (b'20150501 000005587', 1.12083, 1.12086, 0),
#        (b'20150501 000018087', 1.12081, 1.12086, 0), ...,
#        (b'20150501 010142310', 1.12081, 1.12084, 0),
#        (b'20150501 010144560', 1.12079, 1.12083, 0),
#        (b'20150501 010144810', 1.12074, 1.1208, 0)],
#       dtype=[('time', 'S18'), ('start', '<f8'), ('end', '<f8'), ('zero', '<i4')])
